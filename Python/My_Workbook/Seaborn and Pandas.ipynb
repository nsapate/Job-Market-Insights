# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes = True)

# %%
x = np.random.normal(size = 100)
sns.distplot(x)
# Out:
# C:\Users\I322343\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
x = np.random.normal(size = 100)
sns.distplot(x,kde=False, rug= True)

# %%
sns.distplot(x,hist=False, rug= True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-e821adb82de3> in <module>()
# ----> 1 sns.distplot(x, rug= True,shade = True)
#
# TypeError: distplot() got an unexpected keyword argument 'shade'

# %%
sns.kdeplot(x, shade=True);
sns.kdeplot(x, bw=.2, label="bw: 0.2",shade=True)
# Out:
# C:\Users\I322343\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])

# %%
sns.jointplot(x="x", y="y", data=df);

# %%
sns.jointplot(x="x", y="y", data=df, kind="kde")
# Out:
# C:\Users\I322343\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
data = np.random.rand(6,4)
data
# Out:
# array([[ 0.75899901,  0.5585167 ,  0.65129497,  0.88644018],
#        [ 0.40156996,  0.83481922,  0.6708534 ,  0.21029429],
#        [ 0.86805438,  0.18638173,  0.45285066,  0.25556392],
#        [ 0.88528902,  0.22029836,  0.73640869,  0.62913927],
#        [ 0.85485577,  0.25927929,  0.59555271,  0.20697795],
#        [ 0.32827004,  0.45529167,  0.91009375,  0.87504201]])

# %%
dates = pd.date_range('20160101', periods=6)
df = pd.DataFrame(np.random.rand(6,4), index = dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2016-01-01  0.078467  0.276810  0.423202  0.493067
# 2016-01-02  0.122814  0.806724  0.146860  0.497675
# 2016-01-03  0.195618  0.881713  0.890099  0.448754
# 2016-01-04  0.390473  0.673382  0.327088  0.490670
# 2016-01-05  0.982285  0.758873  0.810846  0.006151
# 2016-01-06  0.779979  0.750504  0.860530  0.281863

# %%
df.head(4)
# Out:
#                    A         B         C         D
# 2016-01-01  0.078467  0.276810  0.423202  0.493067
# 2016-01-02  0.122814  0.806724  0.146860  0.497675
# 2016-01-03  0.195618  0.881713  0.890099  0.448754
# 2016-01-04  0.390473  0.673382  0.327088  0.490670

# %%
df.T
# Out:
#    2016-01-01  2016-01-02  2016-01-03  2016-01-04  2016-01-05  2016-01-06
# A    0.078467    0.122814    0.195618    0.390473    0.982285    0.779979
# B    0.276810    0.806724    0.881713    0.673382    0.758873    0.750504
# C    0.423202    0.146860    0.890099    0.327088    0.810846    0.860530
# D    0.493067    0.497675    0.448754    0.490670    0.006151    0.281863

# %%
df[df.A<0]
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df.mean()
# Out:
# A    0.424939
# B    0.691334
# C    0.576437
# D    0.369697
# dtype: float64

# %%
df.apply(np.cumsum)
df.apply(lambda x :x.max()-x.min())
# Out:
# A    0.903818
# B    0.604902
# C    0.743238
# D    0.491524
# dtype: float64

# %%
df.cumsum?
